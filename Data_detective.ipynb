# %% [markdown]
# <a href="https://colab.research.google.com/github/woranun-00/-1/blob/main/Data_detective.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Detective**

# %% [markdown]
# กลุ่มที่ mad cat

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/500px-Cat_November_2010-1a.jpg" width="200">

# %% [markdown]
# # ส่วนใหม่

# %% [markdown]
# **สมาชิก**
#
# 1.นายธีรพัฒน์ สิทธิพันธ์ 683020576-9
#
# 2.น.ส.วรนันท์ สามหาดไทย 683020260-6
#
# 3.นายปิติภัทร บุญหวาน 683020255-9
#
# 4.ปาณธาดา จรุญวงษ์
# 683020254-1
#
#
# 5.น.ส.ประทานพร อุปมาโท
# 683020252-5
#
#
# 6.นางสาวณัฏฐ์ปรัศมน ทวีโภควรกุล 683020241-0

# %% [markdown]
# **1.ไอเดียข้อมูลที่กลุ่มสนใจ**
#
#   ข้อมูลการใช้โซเชียลมีเดียของผู้ใช้งาน เวลาใช้งาน แอปที่ใช้บ่อย จำนวนโพสต์

# %% [markdown]
# **2.ไอเดียสามารถนำไปใช้ประโยชน์ได้อย่างไร**
#
# ข้อมูลดังกล่าวสามารถนำมาวิเคราะห์พฤติกรรมและความสนใจของผู้ใช้งาน เพื่อช่วยพัฒนาและปรับปรุงฟีเจอร์ของแอปพลิเคชันให้ตอบสนองความต้องการของผู้ใช้ได้ดียิ่งขึ้น
